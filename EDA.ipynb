# %%
import numpy as np
import pandas as pd

# %%
data=pd.read_csv("/content/i1.csv")

# %%
data.head()
# Out:
#          Date            Timestamp  Invoice No.             Item Name  Price  \
# 0  2023-09-19  2023-09-19 22:03:44        28389                Kulcha   55.0
# 1  2023-09-19  2023-09-19 22:03:44        28389                Parota   30.0
# 2  2023-09-19  2023-09-19 22:03:44        28389       Mushroom Masala  150.0
# 3  2023-09-19  2023-09-19 22:03:44        28389  Paneer Butter Masala  150.0
# 4  2023-09-19  2023-09-19 22:03:44        28389              Gobi- 65  120.0
#
#    Qty.  Sub Total  Discount   Tax  Final Total  Table No. Server Name  \
# 0   1.0       55.0       0.0  2.76        57.76         16      biller
# 1   4.0      120.0       0.0  6.00       126.00         16      biller
# 2   1.0      150.0       0.0  7.50       157.50         16      biller
# 3   1.0      150.0       0.0  7.50       157.50         16      biller
# 4   1.0      120.0       0.0  6.00       126.00         16      biller
#
#    Covers Variation       Category  HSN
# ...

# %%
data.tail()
# Out:
#             Date            Timestamp  Invoice No.  \
# 7237  2023-07-01  2023-07-01 15:17:24        26194
# 7238  2023-07-01  2023-07-01 15:17:24        26194
# 7239  2023-07-01  2023-07-01 13:12:54        26193
# 7240  2023-07-01  2023-07-01 13:08:33        26192
# 7241  2023-07-01  2023-07-01 13:07:17        26191
#
#                                    Item Name  Price  Qty.  Sub Total  \
# 7237                              Lemon Soda   50.0   1.0       50.0
# 7238                           Mineral Water   20.0   1.0       20.0
# 7239                              Lemon Soda   50.0   3.0      150.0
# 7240                         Oreo Milk Shake  120.0   1.0      120.0
# 7241  Chicken Biriyani With Raitha And Gravy  160.0   2.0      320.0
#
#       Discount   Tax  Final Total  Table No. Server Name  Covers Variation  \
# 7237       0.0   2.5         52.5          3      biller       0       NaN
# 7238       0.0   1.0         21.0          3      biller       0       NaN
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7242 entries, 0 to 7241
# Data columns (total 16 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   Date         7242 non-null   object
#  1   Timestamp    7242 non-null   object
#  2   Invoice No.  7242 non-null   int64
#  3   Item Name    7242 non-null   object
#  4   Price        7242 non-null   float64
#  5   Qty.         7242 non-null   float64
#  6   Sub Total    7242 non-null   float64
#  7   Discount     7242 non-null   float64
#  8   Tax          7242 non-null   float64
#  9   Final Total  7242 non-null   float64
#  10  Table No.    7242 non-null   int64
#  11  Server Name  7242 non-null   object
#  12  Covers       7242 non-null   int64
#  13  Variation    8 non-null      object
#  14  Category     7242 non-null   object
#  15  HSN          0 non-null      float64
# dtypes: float64(7), int64(3), object(6)
# memory usage: 905.4+ KB

# %%
data.describe()
# Out:
#         Invoice No.        Price         Qty.    Sub Total     Discount  \
# count   7242.000000  7242.000000  7242.000000  7242.000000  7242.000000
# mean   27333.419497   122.911627     1.375725   160.320768     1.441421
# std      613.515739    61.393453     0.948374   134.136442     6.649815
# min    26191.000000    20.000000     1.000000    20.000000     0.000000
# 25%    26822.000000    60.000000     1.000000   100.000000     0.000000
# 50%    27356.000000   140.000000     1.000000   160.000000     0.000000
# 75%    27829.000000   160.000000     1.000000   170.000000     0.000000
# max    28389.000000   399.000000    19.000000  3781.000000   288.000000
#
#                Tax  Final Total    Table No.  Covers  HSN
# count  7242.000000  7242.000000  7242.000000  7242.0  0.0
# mean      7.944264   166.823611    20.137255     0.0  NaN
# std       6.662533   139.913793    18.124931     0.0  NaN
# min       0.900000    18.900000     1.000000     0.0  NaN
# ...

# %%
data.describe().T
# Out:
#               count          mean         std      min       25%      50%  \
# Invoice No.  7242.0  27333.419497  613.515739  26191.0  26822.00  27356.0
# Price        7242.0    122.911627   61.393453     20.0     60.00    140.0
# Qty.         7242.0      1.375725    0.948374      1.0      1.00      1.0
# Sub Total    7242.0    160.320768  134.136442     20.0    100.00    160.0
# Discount     7242.0      1.441421    6.649815      0.0      0.00      0.0
# Tax          7242.0      7.944264    6.662533      0.9      4.96      7.5
# Final Total  7242.0    166.823611  139.913793     18.9    103.96    157.5
# Table No.    7242.0     20.137255   18.124931      1.0      5.00     13.0
# Covers       7242.0      0.000000    0.000000      0.0      0.00      0.0
# HSN             0.0           NaN         NaN      NaN       NaN      NaN
#
#                  75%       max
# Invoice No.  27829.0  28389.00
# Price          160.0    399.00
# Qty.             1.0     19.00
# ...

# %%
data.shape
# Out:
# (7242, 16)

# %%
data["Item Name"].unique()
# Out:
# array(['Kulcha', 'Parota', 'Mushroom Masala', 'Paneer Butter Masala',
#        'Gobi- 65', 'Mineral Water', 'Chilly Fish Dry', 'Fish 65',
#        'Prawn Chilli', 'Chicken 65 Boneless', 'Chicken Lolly Pop',
#        'Chicken Biriyani With Raitha And Gravy',
#        'Egg Briyani With Raitha And Chicken Gravy', 'Paneer Noodles',
#        'Plain Briyani With Raitha, Gravy.',
#        'Schezwan Mushroom Fried Rice', 'Chicken Fried Rice',
#        'Schewan Chicken Noodle', 'Schezwan Egg Fried Rice', 'Chicken 65',
#        'Chicken Manchurian Dry', 'Prawn Pepper Fry',
#        'Butter Chicken Gravy', 'Schezwan Chicken Gravy', 'Butter Naan',
#        'Romali Roti (1 No)', 'Roti', 'Chicken Noodles', 'Naan',
#        'French Fries', 'Veg Noodles', 'Pulka (2 No)', 'Kadai Paneer',
#        'Pepper Garlic Chicken Soup', 'Singapore Noodles Veg',
#        'Dragon Chicken', 'Chicken Chettinad Gravy', 'Butter Milk',
#        'Fresh Lemon Juice', 'Veg Fried Rice', 'Pepper Chicken Gravy',
# ...

# %%
data["Item Name"].nunique()
# Out:
# 249

# %%
data.isnull().sum()
# Out:
# Date              0
# Timestamp         0
# Invoice No.       0
# Item Name         0
# Price             0
# Qty.              0
# Sub Total         0
# Discount          0
# Tax               0
# Final Total       0
# Table No.         0
# Server Name       0
# Covers            0
# Variation      7234
# Category          0
# HSN            7242
# dtype: int64

# %%
data["Final Total"].sum()
# Out:
# 1208136.5899999999

# %%
data["Invoice No."].nunique()
# Out:
# 2199

# %%
data["Final Total"].sum()/data["Invoice No."].nunique()#average order value = total amount/invoice number
# Out:
# 549.4027239654388

# %%
data=pd.read_csv
